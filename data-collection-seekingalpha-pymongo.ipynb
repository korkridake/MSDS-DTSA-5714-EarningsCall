# %%
import requests
import io
import json

# %%
# Seeking Alpha
### transcripts/v2/list
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

querystring = {"id":"aapl","size":"20","number":"1"}

headers = {
	"X-RapidAPI-Key": "a2d702a09bmshb89eec70e7c02edp173778jsnc274b366bb28",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(json.dumps(response.json(), indent = 1))
# Out:
# {
#  "data": [
#   {
#    "id": "4574934",
#    "type": "transcript",
#    "attributes": {
#     "publishOn": "2023-02-02T21:33:03-05:00",
#     "isLockedPro": false,
#     "commentCount": 8,
#     "gettyImageUrl": null,
#     "videoPreviewUrl": null,
#     "themes": {},
#     "title": "Apple, Inc. (AAPL) Q1 2023 Earnings Call Transcript",
#     "isPaywalled": false
#    },
#    "relationships": {
#     "author": {
#      "data": {
#       "id": "44211",
#       "type": "author"
#      }
#     },
#     "sentiments": {
#      "data": []
#     },
#     "primaryTickers": {
#      "data": [
#       {
#        "id": "146",
#        "type": "tag"
#       }
#      ]
#     },
#     "secondaryTickers": {
#      "data": []
#     },
#     "otherTags": {
#      "data": [
#       {
#        "id": "49",
#        "type": "tag"
#       }
#      ]
#     }
#    },
#    "links": {
#     "self": "/article/4574934-apple-inc-aapl-q1-2023-earnings-call-transcript"
#    }
#   },
#   {
#    "id": "4550156",
# ...

# %%
# Extract the JSON data from the response
data = response.json()

# %%
# To navigate nested JSON in Python, you can use the dot notation. For example, the following code gets the value of the "name" key in the nested JSON document:
data["data"]
# Out:
# [{'id': '4574934',
#   'type': 'transcript',
#   'attributes': {'publishOn': '2023-02-02T21:33:03-05:00',
#    'isLockedPro': False,
#    'commentCount': 8,
#    'gettyImageUrl': None,
#    'videoPreviewUrl': None,
#    'themes': {},
#    'title': 'Apple, Inc. (AAPL) Q1 2023 Earnings Call Transcript',
#    'isPaywalled': False},
#   'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#    'sentiments': {'data': []},
#    'primaryTickers': {'data': [{'id': '146', 'type': 'tag'}]},
#    'secondaryTickers': {'data': []},
#    'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#   'links': {'self': '/article/4574934-apple-inc-aapl-q1-2023-earnings-call-transcript'}},
#  {'id': '4550156',
#   'type': 'transcript',
#   'attributes': {'publishOn': '2022-10-27T19:46:03-04:00',
#    'isLockedPro': False,
#    'commentCount': 1,
#    'gettyImageUrl': None,
#    'videoPreviewUrl': None,
#    'themes': {},
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://koak2789:oCge9tsmX9AozHKH@clustertesting-msds.bvcccni.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Get the database named "sample_earningcall"
db = client.sample_earningcall

# Get the list of collections in the database
collections = db.list_collection_names()

# Print the list of collections
print(collections)
# Out:
# ['transcripts', 'companylist']

# %%
# Get the collection named "transcripts"
collection = db.companylist

# %%
# Insert the JSON data into the collection
collection.insert_many(data["data"])

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('644fe984417a5b70b8cf4a80'),
#  'id': '4574934',
#  'type': 'transcript',
#  'attributes': {'publishOn': '2023-02-02T21:33:03-05:00',
#   'isLockedPro': False,
#   'commentCount': 8,
#   'gettyImageUrl': None,
#   'videoPreviewUrl': None,
#   'themes': {},
#   'title': 'Apple, Inc. (AAPL) Q1 2023 Earnings Call Transcript',
#   'isPaywalled': False},
#  'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#   'sentiments': {'data': []},
#   'primaryTickers': {'data': [{'id': '146', 'type': 'tag'}]},
#   'secondaryTickers': {'data': []},
#   'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#  'links': {'self': '/article/4574934-apple-inc-aapl-q1-2023-earnings-call-transcript'}}
